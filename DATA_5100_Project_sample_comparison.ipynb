# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

stroke = pd.read_csv('https://raw.githubusercontent.com/kewal97/Stroke-Prediction-Project/main/healthcare-dataset-stroke-data.csv?token=GHSAT0AAAAAAB2DOJ7AKVJ7DYC254JV4DUIY3BWN6Q')

# %%
def BMI_indicator(x):
  if x < 18.5:
    return 'Underweight'
  elif x <25:
    return 'Healthy'
  elif x< 30:
    return 'Overweight'
  elif x < 35:
    return 'Obese Class 1'
  elif x < 40:
    return 'Obese Class 2'
  else:
    return 'Severely Obese'

# %%
stroke['BMI_indicator']= stroke['bmi'].apply(BMI_indicator)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
no_stroke = stroke.loc[stroke["stroke"]==0]
samp_no_stroke = no_stroke.sample(n=1417)

# %% [markdown]
# Gender

# %%
tab1 = pd.crosstab(index=no_stroke['gender'],columns='count')
tab1/tab1.sum()
# Out:
# col_0      count
# gender
# Female  0.586916
# Male    0.412878
# Other   0.000206

# %%
tab2 = pd.crosstab(index=samp_no_stroke['gender'],columns='count')
tab2/tab2.sum()
# Out:
# col_0      count
# gender
# Female  0.573042
# Male    0.426253
# Other   0.000706

# %% [markdown]
# Age

# %%
sns.histplot(data=no_stroke,x="age",bins=17,color="dodgerblue",alpha=0.6,stat='density',kde=True)
sns.histplot(data=samp_no_stroke,x="age",bins=17,color="orange",alpha=0.6,stat='density',kde=True)

# %% [markdown]
# hypertension

# %%
tab3 = pd.crosstab(index=no_stroke['hypertension'],columns='count')
tab3/tab3.sum()
# Out:
# col_0            count
# hypertension
# 0             0.911129
# 1             0.088871

# %%
tab4 = pd.crosstab(index=samp_no_stroke['hypertension'],columns='count')
tab4/tab4.sum()
# Out:
# col_0            count
# hypertension
# 0             0.913197
# 1             0.086803

# %% [markdown]
# heart_disease

# %%
tab5 = pd.crosstab(index=no_stroke['heart_disease'],columns='count')
tab5/tab5.sum()
# Out:
# col_0            count
# heart_disease
# 0              0.95289
# 1              0.04711

# %%
tab6 = pd.crosstab(index=samp_no_stroke['heart_disease'],columns='count')
tab6/tab6.sum()
# Out:
# col_0             count
# heart_disease
# 0              0.949188
# 1              0.050812

# %% [markdown]
# ever_married

# %%
tab7 = pd.crosstab(index=no_stroke['ever_married'],columns='count')
tab7/tab7.sum()
# Out:
# col_0            count
# ever_married
# No            0.355482
# Yes           0.644518

# %%
tab8 = pd.crosstab(index=samp_no_stroke['ever_married'],columns='count')
tab8/tab8.sum()
# Out:
# col_0           count
# ever_married
# No            0.34439
# Yes           0.65561

# %% [markdown]
# work_type

# %%
tab9 = pd.crosstab(index=no_stroke['work_type'],columns='count')
tab9/tab9.sum()
# Out:
# col_0             count
# work_type
# Govt_job       0.128369
# Never_worked   0.004526
# Private        0.571076
# Self-employed  0.155112
# children       0.140918

# %%
tab10 = pd.crosstab(index=samp_no_stroke['work_type'],columns='count')
tab10/tab10.sum()
# Out:
# col_0             count
# work_type
# Govt_job       0.125618
# Never_worked   0.005646
# Private        0.567396
# Self-employed  0.170783
# children       0.130558

# %% [markdown]
# Residence_type

# %%
tab11 = pd.crosstab(index=no_stroke['Residence_type'],columns='count')
tab11/tab11.sum()
# Out:
# col_0              count
# Residence_type
# Rural           0.493726
# Urban           0.506274

# %%
tab12 = pd.crosstab(index=samp_no_stroke['Residence_type'],columns='count')
tab12/tab12.sum()
# Out:
# col_0              count
# Residence_type
# Rural           0.500353
# Urban           0.499647

# %% [markdown]
# avg_glucose_level

# %%
sns.histplot(data=no_stroke,x="avg_glucose_level",bins=17,color="dodgerblue",alpha=0.6,stat='density',kde=True)
sns.histplot(data=samp_no_stroke,x="avg_glucose_level",bins=17,color="orange",alpha=0.6,stat='density',kde=True)

# %% [markdown]
# bmi

# %%
sns.histplot(data=no_stroke,x="bmi",bins=17,color="dodgerblue",alpha=0.6,stat='density',kde=True)
sns.histplot(data=samp_no_stroke,x="bmi",bins=17,color="orange",alpha=0.6,stat='density',kde=True)

# %% [markdown]
# smoking_status

# %%
tab13 = pd.crosstab(index=no_stroke['smoking_status'],columns='count')
tab13/tab13.sum()
# Out:
# col_0               count
# smoking_status
# Unknown          0.307961
# formerly smoked  0.167661
# never smoked     0.370706
# smokes           0.153672

# %%
tab14 = pd.crosstab(index=samp_no_stroke['smoking_status'],columns='count')
tab14/tab14.sum()
# Out:
# col_0               count
# smoking_status
# Unknown          0.309104
# formerly smoked  0.174312
# never smoked     0.375441
# smokes           0.141143
